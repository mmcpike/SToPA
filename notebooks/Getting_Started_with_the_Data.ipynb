# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from datetime import date
from os import listdir
from os.path import isfile, join
from scipy import stats

import sys
sys.path.append('..')
import src as tools

# %%
tools.PROJECT_FOLDER
# Out:
# 'C:/Users/mlmcp/stopa/'

# %% [markdown]
# ## 1.  Set up Envoronment
#
# If you had trouble with with imports above, check that you have all of the necessary requirements installed by running
# ```
# pip install -U -r requirements.txt
# ```
# and if you plan to carry out parsing step
# ```
# pip install -U -r requirements_ocr.txt
# ```
# in the command line from the top level git directory.
#
# ## 2. (Optional) Parse and Process Data
#
# This assumes you already have the necessary parquet files. If you don't have them, then you need to carry out the OCR work which can be done from the command line from the top level git directory by running
# ```
# cd scripts
# python pdf_to_parquet.py 2019
# python pdf_to_parquet.py 2020
# ```
# Warning, this OCR process will take several hours.
#
# If you have the parquet files, then you can proceed as follows.

# %%
for year in [2019,2020]:
    today = str(date.today()).replace("-","_")
    
    # Read available parquet files.
    # my_path = f"{tools.PROJECT_FOLDER}/data/{year}_parquet_logs"
    my_path = f"C:/Users/mlmcp/stopa/data/{year}_parquet_logs"
    files = [f for f in listdir(my_path) if isfile(join(my_path, f))]
    files.sort()

    df_parquet = pd.DataFrame()
    for f in files:
        df_parquet = pd.concat([df_parquet,pd.read_parquet(f"{my_path}/{f}")])

    df_parquet.reset_index(drop = True, inplace = True)

    df = tools.parse_ocr_output(df_parquet, year)
    # filepath = f"{tools.PROJECT_FOLDER}/data/{today}_parsed_{year}.csv"
    filepath = f"C:/Users/mlmcp/stopa/data/{today}_parsed_{year}.csv"
    df.to_csv(filepath)
    print(f"Data printed to: \n {filepath}")
# Out:
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:60: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dt = pd.to_datetime(date[0],infer_datetime_format = True)
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:60: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   dt = pd.to_datetime(date[0],infer_datetime_format = True)
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:78: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_date["date"] = df_date["date"].fillna(method = "ffill")
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:79: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_date["date"] = df_date["date"].fillna(method = "bfill")
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:377: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df["date"] = df["date"].fillna(method = "ffill")
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:176: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2019-01-01 03:41:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"call_datetime"] = pd.to_datetime(f"{y}-{m}-{d} {hr}:{mn}:00")
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:298: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2019-01-01 03:42:00' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"arvd_datetime"] = pd.to_datetime(f"{y}-{m}-{d} {hr}:{mn}:{sc}")
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:300: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2019-01-01 03:42:17' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"clrd_datetime"] = pd.to_datetime(f"{y}-{m}-{d} {hr}:{mn}:{sc}")
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:294: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2019-01-01 11:24:04' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"disp_datetime"] = pd.to_datetime(f"{y}-{m}-{d} {hr}:{mn}:{sc}")
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:296: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '2019-01-01 12:07:56' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"enrt_datetime"] = pd.to_datetime(f"{y}-{m}-{d} {hr}:{mn}:{sc}")
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:203: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Initiated' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"call_type"] = call_type
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:204: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'PARKING CHECK' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"call_reason"] = call_reason
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:222: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'SERVICES RENDERED' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"call_action"] = actions[check_in[0]]
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:246: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'PATROL CRAIG A EICHHAMMER' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"call_taker"] = officer
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:319: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '31' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"responding_units"] = ", ".join([u.strip(" ") for u in units])
# C:\Users\mlmcp\SToPA\notebooks\..\src\processing_tools.py:334: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NORTH STREET' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[i,"street"] = street

# %% [markdown]
# The code above can also be carried from the command line by running the following from the top level git directory
#
# ```
# cd scripts
# python parquet_to_csv.py 2019
# python parquet_to_csv.py 2020
# ```
# This should only take a few minutes.
#
# ## 3. Load Data
#
# Now we can load the data and begin exploring data features and quality.

# %%
# Depending on how you got your csv files, your filenames might different.

# If you just generated the files, then these names should work for you:
today = str(date.today()).replace("-","_")
filename_2019 = f"{today}_parsed_2019.csv"
filename_2020 = f"{today}_parsed_2020.csv"

# If you downloaded the files from Google Drive, then you might use these names instead:
# filename_2019 = "2019_parsed_logs.csv"
# filename_2020 = "2020_parsed_logs.csv"

df_2019 = pd.read_csv(f"{tools.PROJECT_FOLDER}/data/{filename_2019}", index_col = 0)
df_2020 = pd.read_csv(f"{tools.PROJECT_FOLDER}/data/{filename_2020}", index_col = 0)

# %%
df = pd.concat([df_2019, df_2020])
df.reset_index(drop = True, inplace = True)

for col in df.columns:
    if "date" in col:
        df[col] = pd.to_datetime(df[col])
        
df.head()
# Out:
#         date  change_idx log_num  pdf_page       call_datetime disp_datetime  \
# 0 2019-01-01          12    19-1         1 2019-01-01 03:41:00           NaT
# 1 2019-01-01          35    19-4         1 2019-01-01 08:34:00           NaT
# 2 2019-01-01          64    19-5         1 2019-01-01 08:42:00           NaT
# 3 2019-01-01          90    19-6         1 2019-01-01 08:46:00           NaT
# 4 2019-01-01         116    19-7         1 2019-01-01 08:47:00           NaT
#
#   enrt_datetime       arvd_datetime       clrd_datetime     call_reason  \
# 0           NaT 2019-01-01 03:42:00 2019-01-01 03:42:17   PARKING CHECK
# 1           NaT                 NaT 2019-01-01 08:35:33  BUILDING CHECK
# 2           NaT                 NaT 2019-01-01 08:43:21  BUILDING CHECK
# 3           NaT                 NaT 2019-01-01 08:47:07  BUILDING CHECK
# 4           NaT                 NaT 2019-01-01 08:48:05  BUILDING CHECK
#
#    call_type               call_action                 call_taker  \
# 0  Initiated         SERVICES RENDERED  PATROL CRAIG A EICHHAMMER
# 1      Other  BUILDING CHECKED/SECURED   PATROL DAVID JENNINGS, D
# 2      Other  BUILDING CHECKED/SECURED   PATROL DAVID JENNINGS, D
# 3      Other  BUILDING CHECKED/SECURED   PATROL DAVID JENNINGS, D
# 4      Other  BUILDING CHECKED/SECURED   PATROL DAVID JENNINGS, D
#
#   responding_units            street  \
# 0               31      NORTH STREET
# 1               34  COLD SPRING ROAD
# 2               34  LONGVIEW TERRACE
# 3               34    FRENIER AVENUE
# 4               34    HARWOOD STREET
#
#                                            narrative
# 0                                                  7
# 1  Narrative: checked Narrative: done Narrative: ...
# 2         Narrative: checked Narrative: Checked 0208
# 3         Narrative: checked Narrative: Checked 0159
# 4         Narrative: checked Narrative: Checked 0201

# %% [markdown]
# ## Verify Data Quality

# %%
df.count()/df.shape[0]*100
# Out:
# date                100.000000
# change_idx          100.000000
# log_num             100.000000
# pdf_page            100.000000
# call_datetime        90.124703
# disp_datetime        18.528803
# enrt_datetime        13.863786
# arvd_datetime        65.951431
# clrd_datetime        74.206089
# call_reason         100.000000
# call_type           100.000000
# call_action         100.000000
# call_taker          100.000000
# responding_units     82.788913
# street              100.000000
# narrative            99.929318
# dtype: float64

# %%
fig, ax = plt.subplots(figsize = (12,5))
ax.plot(pd.to_datetime(df["date"]).values, df.index, color = "#56B4E9")
ax.set_xticks = pd.date_range("2019-01-01","2021-01-01", freq = "M")
ax.set_title("Sequential log dates in 2019-2020", fontsize = 18)
plt.show()

# %%
date_series = pd.Series(df["date"].value_counts())
date_series.sort_index(inplace = True)

height = date_series.rolling(window = 7).mean().values
x = date_series.rolling(window = 7).mean().index

fig, ax = plt.subplots(figsize = (12,6))
ax.plot(x, height, color = "#56B4E9")
ax.set_xlabel("date")
ax.set_ylabel("Number of Recorder Logs")

plt.title("7-Day Rolling Average Log Count by Date in 2019-2020", fontsize = 18)
plt.show()

# %%
cats = df["call_taker"].value_counts().to_dict()
fig, ax = plt.subplots(figsize = (10,6))


c = ["#56B4E9" if not c in ['PATROL CRAIG A EICHHAMMER','SERGEANT SCOTT E MCGOWAN'] else "#E69F00" for c in cats.keys()]
ax.barh(y = list(cats.keys()), width = list(cats.values()), color = c)

plt.show()

# %% [markdown]
# ## Validation Function
#
# You'll need the OCR tools to do this.  This just prints a random log and the associated parsed entry for a visual sanity check.

# %%
# tools.confirm_parsed_log_entry(df, entry_index = None)
